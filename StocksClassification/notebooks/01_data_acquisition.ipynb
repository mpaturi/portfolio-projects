# %% [markdown]
# # 01 – Data acquisition
#
# Purpose: download 5 years of daily OHLCV data for AAPL, AMZN, MSFT, VOO, and SPY from Yahoo Finance using the `yfinance` library and save one CSV per ticker in `data/raw/`.

# %% [markdown]
# # 01 – Data acquisition
#
# Purpose: Download 5 years of daily OHLCV data for AAPL, AMZN, MSFT, VOO, and SPY from Yahoo Finance using the `yfinance` library, and save one raw CSV per ticker in `data/raw/`.

# %%
import os
import sys
from pathlib import Path

print("CWD:", os.getcwd())

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# CWD: c:\Users\milli\Desktop\CodeForGit\1BIProjects\portfolio-projects\StocksClassification\notebooks
# PROJECT_ROOT: C:\Users\milli\Desktop\CodeForGit\1BIProjects\portfolio-projects\StocksClassification

# %%
from importlib import reload

import pandas as pd

from src import config
import src.data_acquisition as da

# Handy during development to pick up changes in src/
reload(da)

config.TICKERS, config.START_DATE, config.END_DATE
# Out:
# (['AAPL', 'AMZN', 'MSFT', 'VOO', 'SPY'],
#  datetime.date(2021, 1, 30),
#  datetime.date(2026, 1, 29))

# %%
# Download and save raw CSV files for all configured tickers
da.download_and_save_all_tickers()

# Quick sanity check: list raw files
import os
os.listdir(config.RAW_DATA_DIR)
# Out:
# Saved AAPL data to C:\Users\milli\Desktop\CodeForGit\1BIProjects\portfolio-projects\StocksClassification\data\raw\aapl_prices_raw.csv
# Saved AMZN data to C:\Users\milli\Desktop\CodeForGit\1BIProjects\portfolio-projects\StocksClassification\data\raw\amzn_prices_raw.csv
# Saved MSFT data to C:\Users\milli\Desktop\CodeForGit\1BIProjects\portfolio-projects\StocksClassification\data\raw\msft_prices_raw.csv
# Saved VOO data to C:\Users\milli\Desktop\CodeForGit\1BIProjects\portfolio-projects\StocksClassification\data\raw\voo_prices_raw.csv
# Saved SPY data to C:\Users\milli\Desktop\CodeForGit\1BIProjects\portfolio-projects\StocksClassification\data\raw\spy_prices_raw.csv
# ['aapl_prices_raw.csv',
#  'amzn_prices_raw.csv',
#  'msft_prices_raw.csv',
#  'spy_prices_raw.csv',
#  'voo_prices_raw.csv']

# %%
sample_path = config.RAW_DATA_DIR / "aapl_prices_raw.csv"
aapl_raw = pd.read_csv(sample_path)

aapl_raw.head(), aapl_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1255 entries, 0 to 1254
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1254 non-null   str
#  1   adj_close  1255 non-null   str
#  2   close      1255 non-null   str
#  3   high       1255 non-null   str
#  4   low        1255 non-null   str
#  5   open       1255 non-null   str
#  6   volume     1255 non-null   str
# dtypes: str(7)
# memory usage: 68.8 KB
# (         date           adj_close               close                high  \
#  0         NaN                AAPL                AAPL                AAPL
#  1  2021-02-01  130.57891845703125  134.13999938964844   135.3800048828125
#  2  2021-02-02   131.4063262939453  134.99000549316406  136.30999755859375
#  3  2021-02-03  130.38418579101562  133.94000244140625  135.77000427246094
#  4  2021-02-04  133.74261474609375  137.38999938964844  137.39999389648438
#
# ...
